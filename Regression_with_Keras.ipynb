# %% [markdown]
# <a href="https://colab.research.google.com/github/AryaN7643/AI-/blob/main/Regression_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Use case: Build an ANN model that predicts the Power Energy for Powerplant based data. Independent features: sensor readings related to powerplant machines

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv(r'https://raw.githubusercontent.com/sindhura-nk/Datasets/refs/heads/main/PowerPlant.csv')
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
#   AT: Atmospheric Temperature
#   V: Vaccum
#   AP: Atmospheric Pressure
#   RH: Relative Humidity
#   PE: Power Energy

# %% [markdown]
# ### Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(41)

# %%
df=df.drop_duplicates()

# %% [markdown]
# ## Separate data into X and Y features

# %%
X = df.drop(columns=['PE'])
Y = df[["PE"]]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# ## Data Preprocessing and Data cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(SimpleImputer(strategy='mean'),StandardScaler()).set_output(transform='pandas')

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,Y,train_size=0.85,random_state=21)

# %%
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (8097, 4) (1430, 4) (8097, 1) (1430, 1)

# %% [markdown]
# ## Artificial Neural Network Model Building

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# %%
xtrain.shape
# Out:
# (8097, 4)

# %%
xtrain.shape[1]
# Out:
# 4

# %%
model = Sequential()

# Add the Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add the Hidden layers1
model.add(Dense(units=8,activation='relu'))

# Add the Hidden layer2
model.add(Dense(units=4,activation='relu'))

# Add the output layer
model.add(Dense(units=1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mae'])

# %%
nn = model.fit(xtrain,ytrain,validation_split=0.2,epochs=40)
# Out:
# Epoch 1/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 205961.3438 - mae: 453.5265 - val_loss: 203809.8438 - val_mae: 451.2063
# Epoch 2/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 200918.6406 - mae: 448.0238 - val_loss: 190031.3125 - val_mae: 435.8123
# Epoch 3/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 182653.5469 - mae: 427.1012 - val_loss: 154203.8594 - val_mae: 391.5028
# Epoch 4/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 142383.8438 - mae: 374.7852 - val_loss: 105885.8672 - val_mae: 317.2727
# Epoch 5/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95933.5938 - mae: 297.9629 - val_loss: 66052.6250 - val_mae: 234.9305
# Epoch 6/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 59542.6914 - mae: 221.7321 - val_loss: 42535.6758 - val_mae: 183.0164
# Epoch 7/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39416.4844 - mae: 175.4223 - val_loss: 28752.4473 - val_mae: 147.5666
# Epoch 8/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27541.1289 - mae: 143.9456 - val_loss: 20294.8184 - val_mae: 122.9229
# Epoch 9/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19212.1680 - mae: 118.7738 - val_loss: 15161.0146 - val_mae: 105.9771
# Epoch 10/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14919.4863 - mae: 104.5938 - val_loss: 11559.5039 - val_mae: 91.8265
# Epoch 11/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11031.8730 - mae: 88.9876 - val_loss: 8580.6533 - val_mae: 77.9429
# Epoch 12/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8241.6523 - mae: 76.0540 - val_loss: 6187.6851 - val_mae: 65.1813
# Epoch 13/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6107.5444 - mae: 64.4263 - val_loss: 4459.7017 - val_mae: 54.6212
# Epoch 14/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4241.5854 - mae: 53.2098 - val_loss: 3277.2605 - val_mae: 46.4630
# Epoch 15/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3161.0500 - mae: 45.5411 - val_loss: 2434.0442 - val_mae: 39.7486
# Epoch 16/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2271.4944 - mae: 38.0230 - val_loss: 1834.7533 - val_mae: 34.2015
# Epoch 17/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1731.1215 - mae: 32.9480 - val_loss: 1416.3190 - val_mae: 29.9560
# Epoch 18/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1377.3475 - mae: 29.1401 - val_loss: 1113.7729 - val_mae: 26.2379
# Epoch 19/40
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1048.6051 - mae: 25.2404 - val_loss: 878.3304 - val_mae: 23.3525
# Epoch 20/40
# 147/203 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 881.5135 - mae: 22.7973

# %%
## Plot the learning curve
import matplotlib.pyplot as plt
plt.plot(nn.history['loss'],label='Training Loss')
plt.plot(nn.history['val_loss'],label='Validation Loss')
plt.xlabel("Number of Epochs")
plt.ylabel("Mean Squared Error")
plt.legend()
plt.title("Learning Curve")
plt.show()
